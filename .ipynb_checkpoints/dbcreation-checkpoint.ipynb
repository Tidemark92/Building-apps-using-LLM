# %%
import sqlite3

# %%
#create a database connection
conn = sqlite3.connect('LLM.db', timeout = 10)

#create a cursor object to excute sql commands
cur = conn.cursor()

#create "stokcTable" table
cur.execute('''
CREATE TABLE 'stockTable' (
    ticker TEXT DEFAULT NULL,
    created_at DATETIME DEFAULT NULL,
    open REAL DEFAULT NULL,
    high REAL DEFAULT NULL,
    low REAL DEFAUL NULL,
    close REAL DEFAULT NULL,
    volume INTEGER DEFAULT NULL
)
''')

#create newssentiment table

cur.execute('''
CREATE TABLE newsSentiment(
    title TEXT,
    url TEXT,
    time_published DATETIME,
    authors TEXT,
    summary TEXT,
    banner_image TEXT,
    source TEXT,
    category_within_source TEXT,
    source_domain TEXT
    topic TEXT,
    topic_relevance_score TEXT,
    overall_sentiment_score REAL,
    overall_sentiment_label TEXT
)
''')

#create companyinfo table

cur.execute('''
CREATE TABLE companyinfo(
ticker TEXT PRIMARY KEY,
AssetType TEXT,
Name TEXT,
Description TEXT,
CIK TEXT,
Exchange TEXT,
Currency TEXT,
Country TEXT,
Sector TEXT,
Industry TEXT,
Address TEXT,
FiscalYearEnd TEXT,
LatestQuarter DATE,
MarketCapitalization INTEGER,
EBITDA INTEGER,
PERatio REAL,
PEGRatio REAL,
BookValue REAL,
DividendPerShare REAL,
DividendYield REAL,
EPS REAL,
RevenuePerShareTTM REAL,
ProfitMargin REAL,
OperatingMarginTTM REAL,
ReturnOnAssetsTTM REAL,
ReturnOnEquityTTM REAL,
RevenueTTM INTEGER,
GrossProfitTTM INTEGER,
DilutedEPSTTM REAL,
QuarterlyEarningsGrowthYOY REAL,
QuarterlyRevenueGrowthYOY REAL,
AnalystTargetPrice REAL,
TrailingPE REAL,
ForwardPE REAL,
PriceToSalesRatioTTM REAL,
PriceToBookRatio REAL,
EVToRevenue REAL,
EVToEBITDA REAL,
Beta REAL,
"52WeekHigh" REAL,
"52WeekLow" REAL,
"50DayMovingAverage" REAL,
"200DayMovingAverage" REAL,
SharesOutstanding INTEGER,
DividendDate DATE,
ExDividendDate DATE
)
'''
)

#create embeddings table

cur.execute('''
CREATE TABLE embeddings (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    category TEXT,
    question TEXT,
    question_embedding BLOB,
    answer TEXT,
    answer_embedding BLOB,
    created_at DATETIME DEFAULT CURRENT_TIMESTAMP
)
''')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[2], line 10
#       7 cur = conn.cursor()
#       9 #create "stokcTable" table
# ---> 10 cur.execute('''
#      11 CREATE TABLE 'stockTable' (
#      12     ticker TEXT DEFAULT NULL,
#      13     created_at DATETIME DEFAULT NULL,
#      14     open REAL DEFAULT NULL,
#      15     high REAL DEFAULT NULL,
#      16     low REAL DEFAUL NULL,
#      17     close REAL DEFAULT NULL,
#      18     volume INTEGER DEFAULT NULL
#      19 )
#      20 ''')
#      22 #create newssentiment table
#      24 cur.execute('''
#      25 CREATE TABLE newsSentiment(
#      26     title TEXT,
#    (...)
#      39 )
#      40 ''')
#
# OperationalError: table 'stockTable' already exists

# %%
#import packages
import datetime
import getpass
import numpy as np
import openai
import requests
import time

from datetime import datetime
from datetime import timedelta
from dateutil.relativedelta import relativedelta
from langchain.sql_database import SQLDatabase
#from langchain.llms.openai import OpenAI
from langchain.agents.agent_toolkits import SQLDatabaseToolkit
from langchain_community.agent_toolkits import create_sql_agent
#from openai.embeddings_utils import get_embeddings

# %%
#set api keys

alpha_vantage_apikey = getpass.getpass("enter alphavantage apikey here")
openai_apikey = getpass.getpass("enter openai apikey here")
elevenlabs_apikey = getpass.getpass("enter elevenlabs apikey here")
# Out:
# enter alphavantage apikey here ········
# enter openai apikey here ········
# enter elevenlabs apikey here ········

# %%
#set up the connection to some data store and the ticker list
ticker_list=['TSLA', 'AMZN', 'PLTR']
#conn = sqlite3.connect('LLM.db')

def get_past_months(num_months):
    today = datetime.today()
    months = []

    for months_ago in range(0, num_months):
        target_date = today - relativedelta(months=months_ago)
        months.append(target_date.strftime('%Y-%m'))

    return months

#set the number of months

num_months = 2
year_month_list = get_past_months(num_months)
print(year_month_list)
# Out:
# ['2024-07', '2024-06']

# %%
#pull intraday info for each stock and store it into some database

conn = sqlite3.connect("LLM.db")
cur = conn.cursor()

try:
    for ticker in ticker_list:
        print(ticker)
        #data_list = []
        
        for year_month in year_month_list:
            print(year_month)

            intraday_price_url = "https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol={}&interval=5min&month={}&outputsize=full&apikey={}".format(ticker, year_month, alpha_vantage_apikey)

            r = requests.get(intraday_price_url)

            if r.status_code == 200:
                try:
                    data = r.json()['Time Series (5min)']
                except KeyError:
                    print('Error parsing data; key is not found.')

            else:
                print("Fail to retrieve data: HTTP Status:", r.status_code)
                continue

            for key in data.keys():
                document = data[key]
                document['datetime'] = key
                document['ticker'] = ticker

                document['open'] = float(document['1. open'])
                document['high'] = float(document['2. high'])
                document['low'] = float(document['3. low'])
                document['close'] = float(document['4. close'])
                document['volume'] = int(document['5. volume'])

                #document['open'] = float(document['open'])
                #document['high'] = float(document['high'])
                #document['low'] = float(document['low'])
                #document['close'] = float(document['close'])
                #document['volume'] = int(document['volume'])

                #del document['1. open']
                #del document['2. high']
                #del document['3. low']
                #del document['4. close']
                #del document['5. volume']

                #data_list += [document]

                #inside the loop, create the params dictionary with the correct values
                params = {
                    'datetime': document['datetime'],
                    'ticker': ticker,
                    'open': document['open'],
                    'high': document['high'],
                    'low': document['low'],
                    'close': document['close'],
                    'volume': document['volume']
                    }

                #construct and execute the sql statement
                table_name = 'stockTable'
                stmt = f"INSERT INTO {table_name} (created_at, ticker, open, high, low, close, volume) VALUES (:datetime, :ticker, :open, :high, :low, :close, :volume)"

                cur = conn.cursor()
                cur.execute(stmt, params)

            time.sleep(1) #required to not hit api limits
    
        conn.commit()

except sqlite3.Error as error:
    print("An error occured:", error)
    conn.rollback()

finally:
        cur.close()
        conn.close()
# Out:
# TSLA
# 2024-07
# 2024-06
# AMZN
# 2024-07
# 2024-06
# PLTR
# 2024-07
# 2024-06

# %%
conn = sqlite3.connect('LLM.db')
cur = conn.cursor()

cur.execute("SELECT * FROM stockTable LIMIT 5")
rows = cur.fetchall()

for row in rows:
    print(row)

cur.close()
conn.close()
# Out:
# ('TSLA', '2024-07-08 19:55:00', 252.751, 252.8, 252.66, 252.695, 54335)
# ('TSLA', '2024-07-08 19:50:00', 252.68, 252.8, 252.661, 252.775, 22429)
# ('TSLA', '2024-07-08 19:45:00', 252.65, 252.74, 252.65, 252.66, 12122)
# ('TSLA', '2024-07-08 19:40:00', 252.61, 252.69, 252.6, 252.66, 8703)
# ('TSLA', '2024-07-08 19:35:00', 252.54, 252.668, 252.5, 252.63, 9813)

# %%
#bring in company data

#pull intraday data for each stock and write to LLM.db

conn = sqlite3.connect('LLM.db')
cur = conn.cursor()

try:
    for ticker in ticker_list:
        print(ticker)
        #data_list = []

        company_overview = "https://www.alphavantage.co/query?function=OVERVIEW&symbol={}&outputsize=full&apikey={}".format(ticker, alpha_vantage_apikey)
        r = requests.get(company_overview)

        if r.status_code == 200:
            data = r.json()
        else:
            print('Fail to retrieve data: HTTP status:', r.status_code)
            continue

        data['CIK'] = data['CIK']
        data['MarketCapitalization'] = int(data['MarketCapitalization'])
    
        #assume data['EBITDA'] is a string containing 'None'
        ebitda_str = data['EBITDA']

        #handle the case where EBITDA is 'None'
        if ebitda_str.lower() == 'none':
            data['EBITDA'] = 0
        else:
            data['EBITDA'] = int(ebitda_str)

        PERatio_flt = data['PERatio']

        #handle the case where data['PERatio'] is '-'
        if PERatio_flt == '-':
            data['PERatio'] = 0.0
        else:
            data['PERatio'] = float(PERatio_flt)

        data['PEGRatio'] = float(data['PEGRatio'])
        data['BookValue'] = float(data['BookValue'])

        #assume data['DividendPerShare'] is a string containing 'None'
        dividend_per_share_str = data['DividendPerShare']
        if dividend_per_share_str.lower() == 'none':
            data['DividendPerShare'] = 0.0
        else:
            data['DividendPerShare'] = float(dividend_per_share_str)
        #data['DividendPerShare'] = float(data['DividendPerShare'])
    
        #assume data['DividendYield'] is a string containing 'None'
        dividend_yield_str = data['DividendYield']
        if dividend_yield_str.lower() == 'none':
            data['DividendYield'] = 0.0
        else:
            data['DividendYield'] = float(dividend_yield_str)
        #data['DividendYield'] = float(data['DividendYield'])
    
        data['EPS'] = float(data['EPS'])
        data['RevenuePerShareTTM'] = float(data['RevenuePerShareTTM'])
        data['ProfitMargin'] = float(data['ProfitMargin'])
        data['OperatingMarginTTM'] = float(data['OperatingMarginTTM'])
        data['ReturnOnEquityTTM'] = float(data['ReturnOnEquityTTM'])
        data['ReturnOnAssetsTTM'] = float(data['ReturnOnAssetsTTM'])
        data['RevenueTTM'] = int(data['RevenueTTM'])
        data['GrossProfitTTM'] = int(data['GrossProfitTTM'])
        data['DilutedEPSTTM'] = float(data['DilutedEPSTTM'])
        data['QuarterlyEarningsGrowthYOY'] = float(data['QuarterlyEarningsGrowthYOY'])
        data['QuarterlyRevenueGrowthYOY'] = float(data['QuarterlyRevenueGrowthYOY'])
        data['AnalystTargetPrice'] = float(data['AnalystTargetPrice'])

        #assuming data['TrailingPE'] is a string containing '-'
        trailing_pe_str = data['TrailingPE']
        if trailing_pe_str == '-':
            data['TrailingPE'] = 0.0
        else:
            data['TrailingPE'] = float(trailing_pe_str)

        data['ForwardPE'] = float(data['ForwardPE'])
        data['PriceToSalesRatioTTM'] = float(data['PriceToSalesRatioTTM'])

        #assume that data['PriceToBookRatio'] is a string containing '-'
        price_to_book_ratio_flt = data['PriceToBookRatio']
        if price_to_book_ratio_flt == '-':
            data['PriceToBookRatio'] = 0.0
        else:
            data['PriceToBookRatio'] = float(price_to_book_ratio_flt)

        #assume that data['EVToRevenue'] is a string containing '-'
        ev_to_revenue_str = data['EVToRevenue']
        if ev_to_revenue_str == '-':
            data['EVToRevenue'] = 0.0
        else:
            data['EVToRevenue'] = float(ev_to_revenue_str)

        #assume data['EVToEBITDA'] is a string containing '-'
        ev_to_ebitda_str = data['EVToEBITDA']
        if ev_to_ebitda_str == '-':
            data['EVToEBITDA'] = 0.0
        else:
            data['EVToEBITDA'] = float(ev_to_ebitda_str)

        data['Beta'] = float(data['Beta'])
        data['52WeekHigh'] = float(data['52WeekHigh'])
        data['52WeekLow'] = float(data['52WeekLow'])
        data['50DayMovingAverage'] = float(data['50DayMovingAverage'])
        data['200DayMovingAverage'] = float(data['200DayMovingAverage'])
        data['SharesOutstanding'] = int(data['SharesOutstanding'])

        #assume that data['DividendDate'] is a date possible to be 'None'
        dividend_date_str = data['DividendDate']
        if dividend_date_str == 'None':
            data['DividendDate'] = '9999-12-31'
        else:
            data['DividendDate'] = dividend_date_str

        #assume that data['ExDividendDate'] is a date possible to be 'None'
        ex_dividend_date_str = data['ExDividendDate']
        if ex_dividend_date_str == 'None':
            data['ExDividendDate'] = '9999-12-31'
        else:
            data['ExDividendDate'] = ex_dividend_date_str

        #data_list += [data]

        #inside the loop, create the params dictionary with the correct values
        params = {
                    'Symbol': data['Symbol'],
                    'AssetType': data['AssetType'],
                    'Name': data['Name'],
                    'Description': data['Description'],
                    'CIK': data['CIK'],
                    'Exchange': data['Exchange'],
                    'Currency': data['Currency'],
                    'Country': data['Country'],
                    'Sector': data['Sector'],
                    'Industry': data['Industry'],
                    'Address': data['Address'],
                    'FiscalYearEnd': data['FiscalYearEnd'],
                    'LatestQuarter': data['LatestQuarter'],
                    'MarketCapitalization': data['MarketCapitalization'],
                    'EBITDA': data['EBITDA'],
                    'PERatio': data['PERatio'],
                    'PEGRatio': data['PEGRatio'],
                    'BookValue': data['BookValue'],
                    'DividendPerShare': data['DividendPerShare'],
                    'DividendYield': data['DividendYield'],
                    'EPS': data['EPS'],
                    'RevenuePerShareTTM': data['RevenuePerShareTTM'],
                    'ProfitMargin': data['ProfitMargin'],
                    'OperatingMarginTTM': data['OperatingMarginTTM'],
                    'ReturnOnAssetsTTM': data['ReturnOnAssetsTTM'],
                    'ReturnOnEquityTTM': data['ReturnOnEquityTTM'],
                    'RevenueTTM': data['RevenueTTM'],
                    'GrossProfitTTM': data['GrossProfitTTM'],
                    'DilutedEPSTTM': data['DilutedEPSTTM'],
                    'QuarterlyEarningsGrowthYOY': data['QuarterlyEarningsGrowthYOY'],
                    'QuarterlyRevenueGrowthYOY': data['QuarterlyRevenueGrowthYOY'],
                    'AnalystTargetPrice': data['AnalystTargetPrice'],
                    'TrailingPE': data['TrailingPE'],
                    'ForwardPE': data['ForwardPE'],
                    'PriceToSalesRatioTTM': data['PriceToSalesRatioTTM'],
                    'PriceToBookRatio': data['PriceToBookRatio'],
                    'EVToRevenue': data['EVToRevenue'],
                    'EVToEBITDA': data['EVToEBITDA'],
                    'Beta': data['Beta'],
                    '52WeekHigh': data['52WeekHigh'],
                    '52WeekLow': data['52WeekLow'],
                    '50DayMovingAverage': data['50DayMovingAverage'],
                    '200DayMovingAverage': data['200DayMovingAverage'],
                    'SharesOutstanding': data['SharesOutstanding'],
                    'DividendDate': data['DividendDate'],
                    'ExDividendDate': data['ExDividendDate']
            }

        #construct and execute the sql statement
        table_name = 'companyinfo'
        stmt = f"INSERT INTO {table_name} (ticker, AssetType, Name, Description, CIK, Exchange, Currency, Country, Sector, Industry, Address, FiscalYearEnd, LatestQuarter, MarketCapitalization, EBITDA, PERatio, PEGRatio, BookValue, DividendPerShare, DividendYield, EPS, RevenuePerShareTTM, ProfitMargin, OperatingMarginTTM, ReturnOnAssetsTTM, ReturnOnEquityTTM, RevenueTTM, GrossProfitTTM, DilutedEPSTTM, QuarterlyEarningsGrowthYOY, QuarterlyRevenueGrowthYOY, AnalystTargetPrice, TrailingPE, ForwardPE, PriceToSalesRatioTTM, PriceToBookRatio, EVToRevenue, EVToEBITDA, Beta, '52WeekHigh', '52WeekLow', '50DayMovingAverage', '200DayMovingAverage', SharesOutstanding, DividendDate, ExDividendDate) VALUES (:Symbol, :AssetType, :Name, :Description, :CIK, :Exchange, :Currency, :Country, :Sector, :Industry, :Address, :FiscalYearEnd, :LatestQuarter, :MarketCapitalization, :EBITDA, :PERatio, :PEGRatio, :BookValue, :DividendPerShare, :DividendYield, :EPS, :RevenuePerShareTTM, :ProfitMargin, :OperatingMarginTTM, :ReturnOnAssetsTTM, :ReturnOnEquityTTM, :RevenueTTM, :GrossProfitTTM, :DilutedEPSTTM, :QuarterlyEarningsGrowthYOY, :QuarterlyRevenueGrowthYOY, :AnalystTargetPrice, :TrailingPE, :ForwardPE, :PriceToSalesRatioTTM, :PriceToBookRatio, :EVToRevenue, :EVToEBITDA, :Beta, :52WeekHigh, :52WeekLow, :50DayMovingAverage, :200DayMovingAverage, :SharesOutstanding, :DividendDate, :ExDividendDate)"

        cur.execute(stmt, params)
        conn.commit()

        time.sleep(1)

except sqlite3.Error as error:
    print("An error occured:", error)
    conn.rollback()

finally:
    cur.close()
    conn.close()
# Out:
# TSLA
# AMZN
# PLTR

# %%
conn = sqlite3.connect('LLM.db')
cur = conn.cursor()

cur.execute("SELECT * FROM companyinfo LIMIT 5")
rows = cur.fetchall()

for row in rows:
    print(row)

cur.close()
conn.close()
# Out:
# ('TSLA', 'Common Stock', 'Tesla Inc', "Tesla, Inc. is an American electric vehicle and clean energy company based in Palo Alto, California. Tesla's current products include electric cars, battery energy storage from home to grid-scale, solar panels and solar roof tiles, as well as other related products and services. In 2020, Tesla had the highest sales in the plug-in and battery electric passenger car segments, capturing 16% of the plug-in market (which includes plug-in hybrids) and 23% of the battery-electric (purely electric) market. Through its subsidiary Tesla Energy, the company develops and is a major installer of solar photovoltaic energy generation systems in the United States. Tesla Energy is also one of the largest global suppliers of battery energy storage systems, with 3 GWh of battery storage supplied in 2020.", '1318605', 'NASDAQ', 'USD', 'USA', 'MANUFACTURING', 'MOTOR VEHICLES & PASSENGER CAR BODIES', '3500 DEER CREEK RD, PALO ALTO, CA, US', 'December', '2024-03-31', 806676201000, 12265000000, 64.53, 2.982, 20.19, 0.0, 0.0, 3.92, 29.8, 0.144, 0.055, 0.0472, 0.237, 94745002000, 20853000000, 3.92, -0.534, -0.087, 193.37, 64.53, 67.57, 5.67, 8.35, 12.42, 58.23, 2.313, 299.29, 138.8, 185.38, 205.42, 3189200000, '9999-12-31', '9999-12-31')
# ('AMZN', 'Common Stock', 'Amazon.com Inc', "Amazon.com, Inc. is an American multinational technology company which focuses on e-commerce, cloud computing, digital streaming, and artificial intelligence. It is one of the Big Five companies in the U.S. information technology industry, along with Google, Apple, Microsoft, and Facebook. The company has been referred to as one of the most influential economic and cultural forces in the world, as well as the world's most valuable brand.", '1018724', 'NASDAQ', 'USD', 'USA', 'TRADE & SERVICES', 'RETAIL-CATALOG & MAIL-ORDER HOUSES', '410 TERRY AVENUE NORTH, SEATTLE, WA, US', 'December', '2024-03-31', 2073931153000, 96609001000, 55.82, 1.987, 20.83, 0.0, 0.0, 3.57, 57.13, 0.0638, 0.107, 0.0595, 0.203, 590739997000, 225152000000, 3.57, 2.167, 0.125, 225.21, 55.82, 40.0, 3.209, 8.68, 3.268, 19.57, 1.155, 201.2, 118.35, 185.82, 163.06, 10406600000, '9999-12-31', '9999-12-31')
# ('PLTR', 'Common Stock', 'Palantir Technologies\xa0Inc', 'Palantir Technologies Inc. creates and implements software platforms for the intelligence community in the United States to assist in counterterrorism investigations and operations. The company is headquartered in Denver, Colorado.', '1321655', 'NYSE', 'USD', 'USA', 'TECHNOLOGY', 'SERVICES-PREPACKAGED SOFTWARE', '1555 BLAKE STREET, SUITE 250, DENVER, CO, US', 'December', '2024-03-31', 60638487000, 230204000, 226.92, 1.735, 1.695, 0.0, 0.0, 0.12, 1.074, 0.128, 0.128, 0.029, 0.0913, 2334164000, 1497322000, 0.12, 4.018, 0.208, 21.45, 226.92, 68.49, 22.54, 14.43, 21.0, 170.56, 2.705, 27.99, 13.68, 22.93, 20.39, 2130340000, '9999-12-31', '9999-12-31')

# %%
#bring in news sentiment

conn = sqlite3.connect("LLM.db")
cur = conn.cursor()

try:
    for ticker in ticker_list:
        print(ticker)
        #data_list = []

        for i in year_month_list:
            date_object = datetime.strptime(i, '%Y-%m')
            print(date_object)
            output_date = date_object.strftime('%Y%m%d') + "T0000"

            #get previous month from the 'date_object'
            previous_month_date = date_object - relativedelta(months=1)
            previous_month_date = previous_month_date.strftime('%Y%m%d')+"T0000"

            #update 'date_object'
            date_object = previous_month_date

            #grab info about news sentiment from Alpha Vantage
            news_and_sentiment = 'https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers={}&time_from={}&time_to={}&limit=100&outputsize=full&apikey={}'.format(ticker, previous_month_date, output_date, alpha_vantage_apikey)
            r = requests.get(news_and_sentiment)

            data = r.json()
            feed = data.get("feed")

            print(type(feed))

            for item in feed:
                #print(type(item))
                #print(item)
                if not isinstance(item, dict):
                    print("expect item to be a dictionary but get:", type(item))
                    print(item)
                    continue
                #item['title'] = str(item['title'])
                #item['url'] = str(item['url'])
                item['time_published'] = datetime.strptime(item['time_published'], '%Y%m%dT%H%M%S').strftime('%Y-%m-%d %H:%M:%S')

                #check if item['authors'] is empty
                if item['authors']:
                    authors_str = str(item['authors'][0])
                else:
                    authors_str = 'No authors available'

                item['authors'] = authors_str

                #item['summary'] = str(item['summary'])
                #item['banner_image'] = str(item['banner_image'])
                #item['source'] = str(item['source'])
                #item['category_within_source'] = str(item['category_within_source'])
                #item['source_domain'] = str(item['source_domain'])
                item['topic'] = item['topics'][0]["topic"]
                item['topic_relevance_score'] = float(item['topics'][0]['relevance_score'])
                #item['overall_sentiment_score'] = float(item['overall_sentiment_score'])
                #item['overall_sentiment_label'] = str(item['overall_sentiment_label'])
                item['ticker'] = item['ticker_sentiment'][0]['ticker']
                item['ticker_relevance_score'] = float(item['ticker_sentiment'][0]['relevance_score'])
                item['ticker_sentiment_score'] = float(item['ticker_sentiment'][0]['ticker_sentiment_score'])
                item['ticker_sentiment_label'] = item['ticker_sentiment'][0]['ticker_sentiment_label']

                #date_list += feed
            
                params = {
                    'title': item['title'],
                    'url': item['url'],
                    'time_published': item['time_published'],
                    'authors': item['authors'],
                    'summary': item['summary'],
                    'banner_image': item['banner_image'],
                    'source': item['source'],
                    'category_within_source': item['category_within_source'],
                    'source_domain': item['source_domain'],
                    'topic': item['topic'],
                    'topic_relevance_score': item['topic_relevance_score'],
                    'overall_sentiment_score': item['overall_sentiment_score'],
                    'overall_sentiment_label': item['overall_sentiment_label'],
                    'ticker': item['ticker'],
                    'ticker_relevance_score': item['ticker_relevance_score'],
                    'ticker_sentiment_score': item['ticker_sentiment_score'],
                    'ticker_sentiment_label': item['ticker_sentiment_label']
                    }

                #construct and execute sql statement
                table_name= 'newsSentiment'
                stmt = f"INSERT INTO {table_name} (title, url, time_published, authors, summary, banner_image, source, category_within_source, source_domain, topic, topic_relevance_score, overall_sentiment_score, overall_sentiment_label, ticker, ticker_relevance_score, ticker_sentiment_score, ticker_sentiment_label) VALUES (:title, :url, :time_published, :authors, :summary, :banner_image, :source, :category_within_source, :source_domain, :topic, :topic_relevance_score, :overall_sentiment_score, :overall_sentiment_label, :ticker, :ticker_relevance_score, :ticker_sentiment_score, :ticker_sentiment_label)"

                print('Executing SQL:', stmt)

                print('With parameters:', params)
                
                cur.execute(stmt, params)
                conn.commit()

                #time.sleep(1)

finally:
        cur.close()
        conn.close()
# Out:
# TSLA
# 2024-07-01 00:00:00
# <class 'list'>
# Executing SQL: INSERT INTO newsSentiment (title, url, time_published, authors, summary, banner_image, source, category_within_source, source_domain, topic, topic_relevance_score, overall_sentiment_score, overall_sentiment_label, ticker, ticker_relevance_score, ticker_sentiment_score, ticker_sentiment_label) VALUES (:title, :url, :time_published, :authors, :summary, :banner_image, :source, :category_within_source, :source_domain, :topic, :topic_relevance_score, :overall_sentiment_score, :overall_sentiment_label, :ticker, :ticker_relevance_score, :ticker_sentiment_score, :ticker_sentiment_label)
# With parameters: {'title': 'Business class: Linda Yaccarino shakes up X amid pressure from Elon Musk over costs', 'url': 'https://www.ft.com/content/b1a56044-b30a-4924-a7c4-7a5c98bc3f89', 'time_published': '2024-06-30 21:03:42', 'authors': 'No authors available', 'summary': 'This article picked by a teacher with suggested questions is part of the Financial Times free schools access programme. Details/registration here. Read our full range of business picks here. • None Key business terms from the article to research Click to read the article below and then answer ...', 'banner_image': 'https://www.ft.com/__origami/service/image/v2/images/ra
 'overall_sentiment_label': 'Somewhat-Bullish', 'ticker': 'APP', 'ticker_relevance_score': 0.495015, 'ticker_sentiment_score': 0.100642, 'ticker_sentiment_label': 'Neutral'}
# Executing SQL: INSERT INTO newsSentiment (title, url, time_published, authors, summary, banner_image, source, category_within_source, source_domain, topic, topic_relevance_score, overall_sentiment_score, overall_sentiment_label, ticker, ticker_relevance_score, ticker_sentiment_score, ticker_sentiment_label) VALUES (:title, :url, :time_published, :authors, :summary, :banner_image, :source, :category_within_source, :source_domain, :topic, :topic_relevance_score, :overall_sentiment_score, :overall_sentiment_label, :ticker, :ticker_relevance_score, :ticker_sentiment_score, :ticker_sentiment_label)
# With parameters: {'title': 'As The Dow And S&P 500 Hit All-Time Highs, Here Are 3 Ways To Profit', 'url': 'https://www.forbes.com/sites/moneyshow/2024/05/17/dow-tags-40k-spx-hits-at-high-here-are-3-ways-to-profit/', 'time_published': '2024-05-17 15:16:02', 'authors': 'MoneyShow', 'summary': 'The Dow is flirting with 40,000. The S&P 500 and Nasdaq are at or near record highs. But which SPECIFIC stocks hold the most promise given the buoyant backdrop? Three MoneyShow expert contributors weigh in with their best ideas in the utility, technology, and consumer cyclical sectors.', 'banner_image': 'https://imageio.forbes.com/specials-images/imageserve/664774a08a93a6e747d2dc74/0x0.jpg?format=jpg&crop=4174,2347,x0,y300,safe&height=900&width=1600&fit=bounds', 'source': 'Forbes', 'category_within_source': 'n/a', 'source_domain': 'www.forbes.com', 'topic': 'Life Sciences', 'topic_relevance_score': 0.25, 'overall_sentiment_score': 0.295312, 'overall_sentiment_label': 'Somewhat-Bullish', 'ticker': 'DKNG', 'ticker_relevance_score': 0.242587, 'ticker_sentiment_score': 0.232071, 'ticker_sentiment_label': 'Somewhat-Bullish'}

# %%
conn = sqlite3.connect("LLM.db", timeout = 10)
cur = conn.cursor()
cur.execute("SELECT * FROM newsSentiment LIMIT 5")
rows = cur.fetchall()
for row in rows:
    print(row)
cur.close()
conn.close()
# Out:
# ('Business class: Linda Yaccarino shakes up X amid pressure from Elon Musk over costs', 'https://www.ft.com/content/b1a56044-b30a-4924-a7c4-7a5c98bc3f89', '2024-06-30 21:03:42', 'No authors available', 'This article picked by a teacher with suggested questions is part of the Financial Times free schools access programme. Details/registration here. Read our full range of business picks here. • None Key business terms from the article to research Click to read the article below and then answer ...', 'https://www.ft.com/__origami/service/image/v2/images/raw/https%3A%2F%2Fd1e00ek4ebabms.cloudfront.net%2Fproduction%2F43dbb1e3-25aa-411f-aa01-04f32aa59b7a.png?source=next-article&fit=scale-down&quality=highest&width=700&dpr=1', 'Financial Times', 'GoogleRSS', 'www.ft.com', '1.0', -0.077687, 'Neutral', 'TSLA', 0.275867, -0.175798, 'Somewhat-Bearish', 'Manufacturing')
# ("Elon Musk Calls Out New Yorker Piece Criticizing Joe Biden: 'So Many Dem Knives In Biden's Back Right Now, He's Basically A Pincushion'", 'https://www.benzinga.com/news/24/06/39565628/elon-musk-calls-out-new-yorker-piece-criticizing-joe-biden-so-many-dem-knives-in-bidens-back-right-n', '2024-06-30 17:38:45', 'Bibhu Pattnaik', 'In a tweet on Sunday, Tesla CEO Elon Musk expressed criticism over the Democratic Party\'s continued support for President Joe Biden, likening him to a "pincushion." What Happened: On Sunday, Musk took to social media platform X to share his thoughts on the current presidential race.', 'https://cdn.benzinga.com/files/images/story/2024/06/30/Elon-Musk.jpeg?width=1200&height=800&fit=crop', 'Benzinga', 'News', 'www.benzinga.com', '1.0', 0.170695, 'Somewhat-Bullish', 'TSLA', 0.244109, 0.182352, 'Somewhat-Bullish', 'Manufacturing')
# ('Aim to make India a core part of the global energy revolution: Ola Electric', 'https://www.business-standard.com/companies/news/aim-to-make-india-a-core-part-of-the-global-energy-revolution-ola-electric-124063000572_1.html', '2024-06-30 15:29:40', 'Peerzada Abrar', 'Bhavish Aggarwal, founder, says leading global products should be made in the country, for India and the world ...', 'https://bsmedia.business-standard.com/_media/bs/img/article/2024-06/29/full/1719660015-9913.jpg?im=FitAndFill=(336,188)', 'Business Standard', 'Companies', 'www.business-standard.com', '0.108179', 0.171817, 'Somewhat-Bullish', 'BICEF', 0.093108, 0.04581, 'Neutral', 'Financial Markets')
# ('Rivian Soars After Volkswagen Investment. Is It Too Late to Buy the Stock?', 'https://www.fool.com/investing/2024/06/30/rivian-soars-volkswagen-investment-buy-stock/', '2024-06-30 13:30:00', 'Geoffrey Seiler', "Here's why the stock may be a better buy today than before the Volkswagen announcement.", 'https://g.foolcdn.com/image/?url=https%3A%2F%2Fg.foolcdn.com%2Feditorial%2Fimages%2F782004%2Fbuy-new-car-driver-seat-sales-sale-test-drive.jpg&op=resize&w=700', 'Motley Fool', 'n/a', 'www.fool.com', '0.158519', 0.158416, 'Somewhat-Bullish', 'TSLA', 0.062597, 0.0, 'Neutral', 'Earnings')
# ('Is It Too Late to Buy Tesla Stock?', 'https://www.fool.com/investing/2024/06/30/is-it-too-late-to-buy-tesla-stock/', '2024-06-30 12:35:00', 'RJ Fulton', "Despite recent struggles, Tesla's bold ventures beyond EVs hint that its most transformative and profitable days are yet to come.", 'https://g.foolcdn.com/image/?url=https%3A%2F%2Fg.foolcdn.com%2Feditorial%2Fimages%2F781755%2Ftwo-teslas-in-a-line-driving-on-road.png&op=resize&w=700', 'Motley Fool', 'n/a', 'www.fool.com', '0.158519', 0.234515, 'Somewhat-Bullish', 'BVLDF', 0.061315, 0.237201, 'Somewhat-Bullish', 'Economy - Monetary')

# %%
#connect the LLM database to OpenAI's LLM using Langchain

#find the uri of LLM.db
import os

#the relative path to LLM.db
path_llmdb = 'LLM.db'

#convert it to an absolute path
absolute_path = os.path.abspath(path_llmdb)

#print(absolute_path)

sqlalchemy_url = f'sqlite:///{absolute_path}'

#create the agent executor
db = SQLDatabase.from_uri(sqlalchemy_url, include_tables=['embeddings', 'companyinfo', 'newsSentiment', 'stockTable'], sample_rows_in_table_info=2)

os.environ['OPENAI_API_KEY'] = openai_apikey

from langchain_openai import OpenAI

llm = OpenAI(openai_api_key = os.environ['OPENAI_API_KEY'], temperature=0, verbose=True)

toolkit = SQLDatabaseToolkit(db=db, llm=llm)

agent_executor = create_sql_agent(
    llm,
    toolkit = toolkit,
    verbose = True,
    prefix = '''
    You are an agent designed to interact with a SQL database called LLM.
    \n It sometimes has Shard and Sort keys in the table schemas, which you can ignore.
    \n Given an input question, create a syntactically correct SQLite query to run, then check the results of the query and return the answer.
    \n If you are asked about similar questions, you should use the dot_product function.

    \n Here are a few examples how to use dot_product functions:
    \n Example 1:
    Q: How similar are the questions and answers?
    A: The query used to find this is:
        
        SELECT
            question,
            answer,
            dot_product(question_embedding, answer_embedding) as similarity
        FROM
            embeddings;
    
    \n Example 2:
    Q: What are the most similar questions in the embeddings table, not including itself?
    A: The query used to find this answer is:
        
        SELECT
            q1.question AS question1,
            q2.question AS question2,
            dot_product(q1.question_embedding, q2.question_embedding) :> float AS score
        FROM
            embeddings q1,
            emdeddings q2
        WHERE
            q1.question != q2.question
        ORDER BY
            score DESC
        LIMIT 5;

    \n Example 3:
    Q: In the embeddings table, which rows are from the chatbot?
    A: The query used to find this answer is:
        
        SELECT
            category,
            question,
            answer
        FROM
            embeddings
        WHERE
            category = 'chatbot'

    \n If you are asked to describe the database, you should run the query SHOW TABLES.
    \n Unless the user specifies the number of examples they wish to obtain, always limit your query to at most {top_k} results.
    \n The question embedding and answer embedding are very long, so don't show them unless specifically asked to.
    \n You can order the results by a relevant column to return the most interesting examples in the database.
    \n Never query for all the columns from a specific table, only ask for the relevant columns given in the question.
    \n You have access to the tools for interacting with the database.
    \n Only use the below tools.
    \n Only use the information returned by the below tools to construct your final answer.
    \n You must double check your query before executing it.
    \n If you get an error before executing a query, rewrite the query and try again up to 3 times.
    \n DO NOT make any DML statements (INSERT, UPDATE, DELETE, DROP, etc.) to the database.
    \n If the qeustion doesn't seem related to the database, just reuturn "I don\'t know" as the answer.\n
    ''',
    format_instructions = '''
    Use the following format:\n
    \n Question: the input question you must answer
    \n Thought: you should always think about what to do
    \n Action: the action to take, should be one of [{tool_names}]
    \n Action Input: the input to the action
    \n Observation: the result of the action
    \n Thought: I now know the final answer
    \n Final Answer: the final answer to the original input question
    \n SQL query used to get the answer: the final sql query used for the final answer
    ''',
    top_k=3,
    max_iterations=5
)

# %%
conn = sqlite3.connect('LLM.db', timeout=10)
cur = conn.cursor()

def dot_product(x, y):
    return sum(a*b for a, b in zip(x, y))

#register the custom dot_product function
conn.create_function('dot_product', 2, dot_product)

cur.close()
conn.close()

# %%
from langchain_openai import OpenAIEmbeddings

#create a function that processes user question with a check in Semantic Cache layer

table_name = 'embeddings'
similarity_threshold = 0.97

#ensure the environment variable is correctly set
openai_api_key = os.getenv('OPENAI_API_KEY')
if not openai_api_key:
    raise ValueError("API key is not set. Please set the OPENAI_API_KEY environment variable.")

def dot_product(v1, v2):
    try:
        #convert inputs from strings to lists
        if isinstance(v1, str):
            v1 = eval(v1)

        if isinstance(v2, str):
            v2 = eval(v2)
            
        return sum(x*y for x, y in zip(v1, v2))
    except Exception as e:
        print("Error in dot_product:", e)
        return 0 #return a defualt value

def process_user_question(question):
    print(f'\n Question asked: {question}')
    category = 'chatbot'

    conn = sqlite3.connect('LLM.db', timeout=10)
    cur = conn.cursor()

    #register the custom dot_product function
    conn.create_function('dot_product', 2, dot_product)

    #get vector embedding from the original question and calculate the elapsed time
    start_time = time.time()
    embed_model = OpenAIEmbeddings(model="text-embedding-3-small", api_key=openai_api_key)
    current_question_embedding = embed_model.embed_documents([question])
    current_question_embedding = [np.array(x, dtype='<f4') for x in current_question_embedding]
    current_question_embedding = ','.join(map(str, current_question_embedding[0])) #serialize
    
    elapsed_time = (time.time() - start_time) * 1000
    print(f"Execution time for getting the question embedding: {elapsed_time:.2f} milliseconds.")

    #params = {
        #'question_embedding': current_question_embedding
    #}

    #check if embedding is similar to existing questions
    #if semantic score < similarity_threshold, then run the agent executor
    #calculate elapsed time for this step

    try:
        stmt = f"SELECT question, answer, question_embedding FROM embeddings WHERE category='chatbot' LIMIT 1;"
    
        start_time = time.time()
        cur.execute(stmt)
        #conn.commit()
        row = cur.fetchone()
        elpased_time = (time.time()-start_time) * 1000
        print(f"Execution time for checking existing questions: {elapsed_time:.2f} milliseconds")

        if row is not None:
            question0, answer, question0_embedding = row
            print(f"\n Closest Matching Row: \n Question: {question0} \n Answer: {answer}")
            #else:
                #print("No results found matching the criteria.")

            if dot_product(current_question_embedding, question0_embedding) > similarity_threshold:
                print('Action to take: using existing answer')
                return answer

            else:
                print('Action to take: Running angent_executor')
                start_time = time.time()
                answer2 = agent_executor.run(question)
                elapsed_time = (time.time() - start_time) * 1000
                print(f"agent_executor execution time: {elapsed_time:.2f} milliseconds")

                #get current time
                created_at = datetime.now().strftime("%Y-%m-%d %H:%M:%S")

                #get the answer embedding and calculate the elapsed time
                start_time = time.time()
                answer_embedding = embed_model.embed_documents([answer2])
                answer_embedding = [np.array(x, dtype='f4') for x in answer_embedding]
                answer_embedding = ','.join(map(str, answer_embedding[0])) #serialize
                elapsed_time = (time.time()-start_time) * 1000
                print(f"Answer embeddings execution time: {elapsed_time:.2f} milliseconds")

                params = {'category': category,
                         'question': question,
                         'question_embedding': current_question_embedding,
                         'answer': answer2,
                         'answer_embedding': answer_embedding,
                         'created_at': created_at}

                #send params details as a row into the LLMDB embeddings table and calculate the elapsed time
                stmt = f"INSERT INTO {table_name} (category, question, question_embedding, answer, answer_embedding, created_at) VALUES (:category, :question, :question_embedding, :answer, :answer_embedding, :created_at)"
                start_time = time.time()

                cur.execute(stmt, params)
                conn.commit()
            
                elapsed_time = (time.time()-start_time)*1000
                print(f"Insert to LLMDB execution time: {elapsed_time:.2f} milliseconds")

                return answer2
    
        #handle known exceptions then return as normal
        else:
            print('No existing rows. Running agent_executor.')
            start_time = time.time()
            answer2 = agent_executor.run(question)
            elapsed_time = (time.time()-start_time) * 1000
            print(f"agent_executor execution time: {elapsed_time:.2f} milliseconds")

            #get current time
            created_at = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
        
            #record the start time
            start_time = time.time()

            answer_embedding = embed_model.embed_documents([answer2])
            answer_embedding = [np.array(x, dtype='f4') for x in answer_embedding]
            answer_embedding = ','.join(map(str, answer_embedding[0])) #serialize

            #calculate the elapsed time
            elapsed_time = (time.time()-start_time) * 1000
            print(f"Answer embedding execution time: {elapsed_time:.2f} milliseconds")

            params = {'category': category,
                     'question': question,
                     'question_embedding': current_question_embedding,
                      'answer': answer2,
                      'answer_embedding': answer_embedding,
                      'created_at': created_at}

            #send to LLMDB
            stmt = f"INSERT INTO {table_name} (category, question, question_embedding, answer, answer_embedding, created_at) VALUES (:category, :question, :question_embedding, :answer, :answer_embedding, :created_at)"
            start_time = time.time()

            cur.execute(stmt, params)
            conn.commit()

            elapsed_time = (time.time()-start_time)*1000
            print(f"Insert to LLMDB execution time: {elapsed_time:.2f} milliseconds")

            return answer2

    finally:
        cur.close()
        conn.close()

# %%
#test on two similar questions
question_1 = 'describe the database'
question_2 = 'describe database'

answer = process_user_question(question_1)
print(f"The answer is: {answer}")
# Out:
#  Question asked: describe the database
# Execution time for getting the question embedding: 304.44 milliseconds.
# Execution time for checking existing questions: 304.44 milliseconds
#
#  Closest Matching Row:
#  Question: describe the database
#  Answer: The database contains the following tables: companyinfo, embeddings, newsSentiment, stockTable
# SQL query used to get the answer: sql_db_list_tables()
# Action to take: using existing answer
# The answer is: The database contains the following tables: companyinfo, embeddings, newsSentiment, stockTable
# SQL query used to get the answer: sql_db_list_tables()

# %%
answer2 = process_user_question(question_2)
print(f"The answer to a similar question is: {answer2}")
# Out:
#  Question asked: describe database
# Execution time for getting the question embedding: 363.71 milliseconds.
# Execution time for checking existing questions: 363.71 milliseconds
#
#  Closest Matching Row:
#  Question: describe the database
#  Answer: The database contains the following tables: companyinfo, embeddings, newsSentiment, stockTable
# SQL query used to get the answer: sql_db_list_tables()
# Action to take: Running angent_executor
#
#
# > Entering new SQL Agent Executor chain...
#  I should use sql_db_schema to get the schema and sample rows for all tables in the database
# Action: sql_db_schema
# Action Input: sql_db_list_tables()Error: table_names {'sql_db_list_tables()'} not found in database I should use sql_db_list_tables first to get a list of tables in the database
# Action: sql_db_list_tables
# Action Input: ""companyinfo, embeddings, newsSentiment, stockTable I now know the final answer
# Final Answer: The database contains four tables: companyinfo, embeddings, newsSentiment, and stockTable.
# SQL query used to get the answer: sql_db_list_tables()
#
# > Finished chain.
# agent_executor execution time: 2374.63 milliseconds
# Answer embeddings execution time: 210.48 milliseconds
# Insert to LLMDB execution time: 7.38 milliseconds
# The answer to a similar question is: The database contains four tables: companyinfo, embeddings, newsSentiment, and stockTable.
# SQL query used to get the answer: sql_db_list_tables()

# %%
question3 = 'what is the highest price of Amazon on 2024-07-08 and what value it is?'
answer3 = process_user_question(question3)

print(f"The answer is: {answer3}")
# Out:
#  Question asked: what is the highest price of Amazon on 2024-07-08 and what value it is?
# Execution time for getting the question embedding: 484.46 milliseconds.
# Execution time for checking existing questions: 484.46 milliseconds
#
#  Closest Matching Row:
#  Question: describe the database
#  Answer: The database contains the following tables: companyinfo, embeddings, newsSentiment, stockTable
# SQL query used to get the answer: sql_db_list_tables()
# Action to take: Running angent_executor
#
#
# > Entering new SQL Agent Executor chain...
#  I should use sql_db_query to query the database for the highest price of Amazon on 2024-07-08
# Action: sql_db_query
# Action Input: SELECT MAX(price) FROM Amazon WHERE date = '2024-07-08'Error: (sqlite3.OperationalError) no such table: Amazon
# [SQL: SELECT MAX(price) FROM Amazon WHERE date = '2024-07-08']
# (Background on this error at: https://sqlalche.me/e/20/e3q8) I should use sql_db_list_tables to check if the table 'Amazon' exists in the database
# Action: sql_db_list_tables
# Action Input: companyinfo, embeddings, newsSentiment, stockTable I should use sql_db_schema to get the schema and sample rows for the 'stockTable' table
# Action: sql_db_schema
# Action Input: stockTable
# CREATE TABLE "stockTable" (
# 	ticker TEXT DEFAULT NULL,
# 	created_at DATETIME DEFAULT NULL,
# 	open REAL DEFAULT NULL,
# 	high REAL DEFAULT NULL,
# 	low REAL,
# 	close REAL DEFAULT NULL,
# 	volume INTEGER DEFAULT NULL
# )
#
# /*
# 2 rows from stockTable table:
# ticker	created_at	open	high	low	close	volume
# TSLA	2024-07-08 19:55:00	252.751	252.8	252.66	252.695	54335
# TSLA	2024-07-08 19:50:00	252.68	252.8	252.661	252.775	22429
# */ I should use sql_db_query to query the database for the highest price of Amazon on 2024-07-08
# Action: sql_db_query
# Action Input: SELECT MAX(close) FROM stockTable WHERE ticker = 'AMZN' AND date = '2024-07-08'Error: (sqlite3.OperationalError) no such column: date
# [SQL: SELECT MAX(close) FROM stockTable WHERE ticker = 'AMZN' AND date = '2024-07-08']
# (Background on this error at: https://sqlalche.me/e/20/e3q8) I should use sql_db_query_checker to double check my query for any errors
# Action: sql_db_query_checker
# Action Input: SELECT MAX(close) FROM stockTable WHERE ticker = 'AMZN' AND created_at = '2024-07-08'
# SELECT MAX(close) FROM stockTable WHERE ticker = 'AMZN' AND created_at = '2024-07-08'
#
# > Finished chain.
# agent_executor execution time: 6530.26 milliseconds
# Answer embeddings execution time: 1130.79 milliseconds
# Insert to LLMDB execution time: 11.36 milliseconds
# The answer is: Agent stopped due to iteration limit or time limit.

# %%
conn = sqlite3.connect('LLM.db', timeout=10)
cur = conn.cursor()

cur.execute("SELECT * FROM embeddings LIMIT 5")
rows = cur.fetchall()

for row in rows:
    print(row)

cur.close()
conn.close()
# Out:
# (1, 'chatbot', 'describe the database', '-0.013240856,0.010568794,0.020735206,-0.020622037,0.017843092,-0.04305479,0.023312962,0.03231624,-0.07665362,0.0033667989,0.035786778,-0.016283864,0.011832522,-0.04561997,0.037220262,0.06694617,-0.00068019715,0.020395698,0.02228186,-0.0011450575,0.035434693,0.024230894,0.05291313,-0.025727248,0.0045519373,9.322748e-05,-0.010763697,-0.009694872,0.004055248,-0.06096075,-0.018459238,-0.02804094,0.050800625,0.021338778,0.046978004,0.027940344,0.061363135,0.012058862,0.03769809,-0.002098355,-0.017742496,-0.018019132,-0.020798078,-0.011379844,0.0006609426,0.013844429,0.0008322689,-0.021527395,0.026607458,0.0054384335,-0.057792,-0.008651196,-0.016409608,0.044664312,0.024369212,-0.0151521675,0.02120046,0.037999876,-0.014070768,0.008638621,-0.025236845,-0.015894057,-0.012329211,0.02448238,-0.042073984,-0.039886035,-0.051404197,0.07363576,-0.016434757,0.019666381,0.06754974,0.03709452,-0.03231624,0.017654475,0.03324675,-0.016132971,-0.027311623,0.00069355743,-0.0039389348,0.020886099,-0.007224,0.01615812,0.023400981,0.008952982,0.015064146,-0.026406266,-0.008236241,